# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import keras.backend as K
from time import perf_counter
import matplotlib.pyplot as plt
from keras import layers, models
from keras.utils import plot_model
from keras.metrics import Precision, Recall, AUC
from keras.callbacks import LearningRateScheduler
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load the precomputed folds
df = pd.read_csv('/kaggle/input/exp105-train-5-folds/exp105_train_5_folds.csv')

# Manually choose the fold (e.g., fold 0)
fold = 3
train_df = df[df['fold'] != fold]
val_df   = df[df['fold'] == fold]

IMG_SIZE = 224
BATCH_SIZE = 16

# Initialize image data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen   = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    x_col='filepath',
    y_col='label',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_dataframe(
    val_df,
    x_col='filepath',
    y_col='label',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# This directory remains the same for all folds.
test_dir = '/kaggle/input/pneumonia-imbalance-chest-x-ray-dataset/test'

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Typically, you don't shuffle test data
)
# Out:
# Found 13801 validated image filenames belonging to 6 classes.
# Found 3450 validated image filenames belonging to 6 classes.
# Found 4929 images belonging to 6 classes.

# %%
class NegativeImageLayer(layers.Layer):
    def __init__(self, **kwargs):
        super(NegativeImageLayer, self).__init__(**kwargs)

    def call(self, inputs):
        return tf.negative(inputs)

    def get_config(self):
        config = super(NegativeImageLayer, self).get_config()
        return config

class TwiceMaxMinPooling2D(layers.Layer):
    def __init__(self, pool_size=(2, 2), strides=2, padding="SAME", **kwargs):
        super(TwiceMaxMinPooling2D, self).__init__(**kwargs)
        self.pool_size = pool_size
        self.strides = strides
        self.padding = padding

    def call(self, inputs, *args, **kwargs):
        # Max pooling
        max_pool = tf.keras.layers.MaxPooling2D(
            pool_size=self.pool_size, strides=self.strides, padding=self.padding
        )(inputs)

        # Min pooling
        neg_inputs = -inputs
        neg_max_pool = tf.keras.layers.MaxPooling2D(
            pool_size=self.pool_size, strides=self.strides, padding=self.padding
        )(neg_inputs)
        min_pool = -neg_max_pool

        # Twice max - min
        return 2 * max_pool - min_pool

    def get_config(self):
        config = super().get_config()
        config.update({
            "pool_size": self.pool_size,
            "strides": self.strides,
            "padding": self.padding
        })
        return config

# %%
inputs = layers.Input(shape=(224, 224, 3), name="Input")

# Block 1
x = layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv1")(inputs)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv1")(x)
x = layers.BatchNormalization()(x)
blk1 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool1")(x)

# Block 2
x = layers.Conv2D(64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv2")(blk1)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv2")(x)
x = layers.BatchNormalization()(x)
blk2 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool2")(x)

# Block 3
x = layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv3")(blk2)
x = layers.MaxPooling2D(pool_size=2, strides=2, padding="same", name="MaxPool3")(x)
x = layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv4")(x)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv3")(x)
x = layers.BatchNormalization()(x)
blk3 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool4")(x)

# Block 4
x = layers.Conv2D(256, kernel_size=(3, 3), padding="same", activation="relu", name="Conv5")(blk3)
x = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool5")(x)
x = layers.Conv2D(512, kernel_size=(3, 3), padding="same", activation="relu", name="Conv6")(x)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv4")(x)
blk4 = layers.BatchNormalization()(x)

# Block 5
y = NegativeImageLayer()(blk2)
y = TwiceMaxMinPooling2D(pool_size=(3, 3))(y)
y = layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv7")(y)
y = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool7")(y)
y = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv5")(y) 
y = layers.Conv2D(64, kernel_size=(5, 5), padding="same", activation="relu", name="Conv8")(y)
y = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool8")(y)
y = layers.Conv2D(224, kernel_size=(3, 3), padding="same", activation="relu", name="Conv9")(y)
blk5 = layers.BatchNormalization()(y)


x = layers.Concatenate(name="DirectConcat")([blk4, blk5])

x = layers.GlobalAveragePooling2D(name="GAP")(x)

outputs = layers.Dense(6, activation="softmax", name="Output")(x)

model = models.Model(inputs=inputs, outputs=outputs)

# %%
class CustomMetrics(tf.keras.metrics.Metric):
    def __init__(self, metric_name, **kwargs):
        super(CustomMetrics, self).__init__(name=metric_name, **kwargs)
        self.metric_name = metric_name
        self.tp = self.add_weight(name="tp", initializer="zeros")
        self.tn = self.add_weight(name="tn", initializer="zeros")
        self.fp = self.add_weight(name="fp", initializer="zeros")
        self.fn = self.add_weight(name="fn", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        y_pred = tf.round(tf.clip_by_value(y_pred, 0, 1))
        y_true = tf.round(tf.clip_by_value(y_true, 0, 1))

        self.tp.assign_add(tf.reduce_sum(y_true * y_pred))
        self.tn.assign_add(tf.reduce_sum((1 - y_true) * (1 - y_pred)))
        self.fp.assign_add(tf.reduce_sum((1 - y_true) * y_pred))
        self.fn.assign_add(tf.reduce_sum(y_true * (1 - y_pred)))

    def result(self):
        if self.metric_name == "f1_score":
            precision = self.tp / (self.tp + self.fp + tf.keras.backend.epsilon())
            recall = self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
            return 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
        elif self.metric_name == "specificity":
            return self.tn / (self.tn + self.fp + tf.keras.backend.epsilon())
        elif self.metric_name == "sensitivity":
            return self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
        elif self.metric_name == "mcc":
            numerator = (self.tp * self.tn - self.fp * self.fn)
            denominator = tf.math.sqrt(
                (self.tp + self.fp) * (self.tp + self.fn) *
                (self.tn + self.fp) * (self.tn + self.fn)
            )
            return numerator / (denominator + tf.keras.backend.epsilon())
        else:
            raise ValueError(f"Unknown metric name: {self.metric_name}")

    def reset_states(self):
        self.tp.assign(0)
        self.tn.assign(0)
        self.fp.assign(0)
        self.fn.assign(0)

def create_metrics():
    return [
        Precision(name="precision"),
        Recall(name="recall"),
        CustomMetrics(metric_name="f1_score"),
        CustomMetrics(metric_name="specificity"),
        CustomMetrics(metric_name="sensitivity"),
        CustomMetrics(metric_name="mcc"),
        AUC(name="auc"),
    ]

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'] + create_metrics()
)

# %%
TOTAL_EPOCHS = 25
INITIAL_LEARNING_RATE = 0.75e-4
DECAY_RATE = 0.96

def learning_rate_scheduler(epoch, current_learning_rate):
    """
    A function that returns the learning rate for each epoch.

    Args:
        epoch (int): The current epoch.
        current_learning_rate (float): The current learning rate.

    Returns:
        float: The new learning rate.
    """
    if epoch < (TOTAL_EPOCHS / 3):
        new_learning_rate = INITIAL_LEARNING_RATE
    else:
        new_learning_rate = current_learning_rate * DECAY_RATE

    return new_learning_rate

# %%
learning_rate_callback = LearningRateScheduler(learning_rate_scheduler)

# %%
start_time = perf_counter()
history = model.fit(
    train_generator,
    callbacks=[learning_rate_callback],
    validation_data=val_generator,
    epochs=TOTAL_EPOCHS,
    steps_per_epoch=len(train_df) // BATCH_SIZE,
    validation_steps=len(val_df) // BATCH_SIZE
)
end_time = perf_counter()
# Out:
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 166s 168ms/step - accuracy: 0.6910 - auc: 0.9102 - f1_score: 0.6071 - loss: 0.9243 - mcc: 0.5841 - precision: 0.8138 - recall: 0.5047 - sensitivity: 0.5047 - specificity: 0.9795 - val_accuracy: 0.4797 - val_auc: 0.8650 - val_f1_score: 0.4730 - val_loss: 1.5014 - val_mcc: 0.3713 - val_precision: 0.4863 - val_recall: 0.4605 - val_sensitivity: 0.4605 - val_specificity: 0.9027 - learning_rate: 7.5000e-05
# Epoch 2/25
#   1/862 ━━━━━━━━━━━━━━━━━━━━ 1:01 71ms/step - accuracy: 0.6875 - auc: 0.9742 - f1_score: 0.7097 - loss: 0.5225 - mcc: 0.6543 - precision: 0.7333 - recall: 0.6875 - sensitivity: 0.6875 - specificity: 0.9500
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6875 - auc: 0.9742 - f1_score: 0.7097 - loss: 0.5225 - mcc: 0.6543 - precision: 0.7333 - recall: 0.6875 - sensitivity: 0.6875 - specificity: 0.9500 - val_accuracy: 0.6000 - val_auc: 0.8680 - val_f1_score: 0.6000 - val_loss: 1.2105 - val_mcc: 0.5200 - val_precision: 0.6000 - val_recall: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.9200 - learning_rate: 7.5000e-05
# Epoch 3/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.8753 - auc: 0.9863 - f1_score: 0.8740 - loss: 0.3580 - mcc: 0.8500 - precision: 0.8972 - recall: 0.8520 - sensitivity: 0.8520 - specificity: 0.9805 - val_accuracy: 0.8445 - val_auc: 0.9771 - val_f1_score: 0.8447 - val_loss: 0.4583 - val_mcc: 0.8142 - val_precision: 0.8548 - val_recall: 0.8349 - val_sensitivity: 0.8349 - val_specificity: 0.9716 - learning_rate: 7.5000e-05
# Epoch 4/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 66us/step - accuracy: 0.8750 - auc: 0.9937 - f1_score: 0.8750 - loss: 0.2575 - mcc: 0.8500 - precision: 0.8750 - recall: 0.8750 - sensitivity: 0.8750 - specificity: 0.9750 - val_accuracy: 0.9000 - val_auc: 0.9270 - val_f1_score: 0.9000 - val_loss: 0.6346 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 7.5000e-05
# Epoch 5/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 87ms/step - accuracy: 0.9134 - auc: 0.9924 - f1_score: 0.9110 - loss: 0.2545 - mcc: 0.8935 - precision: 0.9219 - recall: 0.9004 - sensitivity: 0.9004 - specificity: 0.9847 - val_accuracy: 0.8282 - val_auc: 0.9795 - val_f1_score: 0.8278 - val_loss: 0.4306 - val_mcc: 0.7942 - val_precision: 0.8412 - val_recall: 0.8148 - val_sensitivity: 0.8148 - val_specificity: 0.9692 - learning_rate: 7.5000e-05
# Epoch 6/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 65us/step - accuracy: 0.9375 - auc: 0.9953 - f1_score: 0.9375 - loss: 0.1887 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.9000 - val_auc: 0.9960 - val_f1_score: 0.8421 - val_loss: 0.2755 - val_mcc: 0.8141 - val_precision: 0.8889 - val_recall: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.9800 - learning_rate: 7.5000e-05
# Epoch 7/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 77s 89ms/step - accuracy: 0.9228 - auc: 0.9948 - f1_score: 0.9231 - loss: 0.2101 - mcc: 0.9079 - precision: 0.9297 - recall: 0.9166 - sensitivity: 0.9166 - specificity: 0.9861 - val_accuracy: 0.8177 - val_auc: 0.9628 - val_f1_score: 0.8169 - val_loss: 0.5795 - val_mcc: 0.7820 - val_precision: 0.8407 - val_recall: 0.7945 - val_sensitivity: 0.7945 - val_specificity: 0.9699 - learning_rate: 7.5000e-05
# Epoch 8/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 64us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 0.9677 - loss: 0.1048 - mcc: 0.9623 - precision: 1.0000 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 1.0000 - val_accuracy: 0.6000 - val_auc: 0.9160 - val_f1_score: 0.6000 - val_loss: 1.0432 - val_mcc: 0.5200 - val_precision: 0.6000 - val_recall: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.9200 - learning_rate: 7.5000e-05
# Epoch 9/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 77s 89ms/step - accuracy: 0.9391 - auc: 0.9965 - f1_score: 0.9389 - loss: 0.1714 - mcc: 0.9267 - precision: 0.9435 - recall: 0.9343 - sensitivity: 0.9343 - specificity: 0.9888 - val_accuracy: 0.8913 - val_auc: 0.9874 - val_f1_score: 0.8912 - val_loss: 0.3151 - val_mcc: 0.8695 - val_precision: 0.8943 - val_recall: 0.8881 - val_sensitivity: 0.8881 - val_specificity: 0.9790 - learning_rate: 7.5000e-05
# Epoch 10/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - accuracy: 0.8125 - auc: 0.9898 - f1_score: 0.8387 - loss: 0.3130 - mcc: 0.8083 - precision: 0.8667 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.9750 - val_accuracy: 0.9000 - val_auc: 0.9980 - val_f1_score: 0.9000 - val_loss: 0.1530 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 7.2000e-05
# Epoch 11/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 87ms/step - accuracy: 0.9519 - auc: 0.9976 - f1_score: 0.9518 - loss: 0.1360 - mcc: 0.9422 - precision: 0.9548 - recall: 0.9488 - sensitivity: 0.9488 - specificity: 0.9910 - val_accuracy: 0.9084 - val_auc: 0.9923 - val_f1_score: 0.9082 - val_loss: 0.2432 - val_mcc: 0.8899 - val_precision: 0.9106 - val_recall: 0.9058 - val_sensitivity: 0.9058 - val_specificity: 0.9822 - learning_rate: 6.9120e-05
# Epoch 12/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 62us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0279 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.9000 - val_auc: 0.9940 - val_f1_score: 0.9000 - val_loss: 0.2044 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 6.6355e-05
# Epoch 13/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 77s 89ms/step - accuracy: 0.9612 - auc: 0.9982 - f1_score: 0.9599 - loss: 0.1161 - mcc: 0.9519 - precision: 0.9632 - recall: 0.9565 - sensitivity: 0.9565 - specificity: 0.9927 - val_accuracy: 0.7276 - val_auc: 0.9412 - val_f1_score: 0.7283 - val_loss: 0.9243 - val_mcc: 0.6745 - val_precision: 0.7343 - val_recall: 0.7224 - val_sensitivity: 0.7224 - val_specificity: 0.9477 - learning_rate: 6.3701e-05
# Epoch 14/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 73us/step - accuracy: 0.9375 - auc: 0.9992 - f1_score: 0.9375 - loss: 0.0802 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.6000 - val_auc: 0.8950 - val_f1_score: 0.6316 - val_loss: 1.3519 - val_mcc: 0.5636 - val_precision: 0.6667 - val_recall: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.9400 - learning_rate: 6.1153e-05
# Epoch 15/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 88ms/step - accuracy: 0.9744 - auc: 0.9992 - f1_score: 0.9742 - loss: 0.0821 - mcc: 0.9691 - precision: 0.9755 - recall: 0.9729 - sensitivity: 0.9729 - specificity: 0.9951 - val_accuracy: 0.8788 - val_auc: 0.9864 - val_f1_score: 0.8802 - val_loss: 0.3341 - val_mcc: 0.8565 - val_precision: 0.8867 - val_recall: 0.8738 - val_sensitivity: 0.8738 - val_specificity: 0.9777 - learning_rate: 5.8707e-05
# Epoch 16/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 71us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0380 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.9000 - val_auc: 0.9860 - val_f1_score: 0.9000 - val_loss: 0.3657 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 5.6359e-05
# Epoch 17/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 88ms/step - accuracy: 0.9779 - auc: 0.9990 - f1_score: 0.9778 - loss: 0.0711 - mcc: 0.9734 - precision: 0.9794 - recall: 0.9763 - sensitivity: 0.9763 - specificity: 0.9959 - val_accuracy: 0.9265 - val_auc: 0.9912 - val_f1_score: 0.9263 - val_loss: 0.2334 - val_mcc: 0.9116 - val_precision: 0.9282 - val_recall: 0.9244 - val_sensitivity: 0.9244 - val_specificity: 0.9857 - learning_rate: 5.4104e-05
# Epoch 18/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 66us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0722 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.9000 - val_auc: 0.9980 - val_f1_score: 0.9000 - val_loss: 0.1269 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 5.1940e-05
# Epoch 19/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 88ms/step - accuracy: 0.9834 - auc: 0.9997 - f1_score: 0.9830 - loss: 0.0543 - mcc: 0.9796 - precision: 0.9842 - recall: 0.9818 - sensitivity: 0.9818 - specificity: 0.9969 - val_accuracy: 0.9299 - val_auc: 0.9920 - val_f1_score: 0.9295 - val_loss: 0.2183 - val_mcc: 0.9155 - val_precision: 0.9312 - val_recall: 0.9279 - val_sensitivity: 0.9279 - val_specificity: 0.9863 - learning_rate: 4.9862e-05
# Epoch 20/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 68us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0210 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.9000 - val_auc: 0.9950 - val_f1_score: 0.9000 - val_loss: 0.1960 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 4.7868e-05
# Epoch 21/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 87ms/step - accuracy: 0.9860 - auc: 0.9998 - f1_score: 0.9858 - loss: 0.0420 - mcc: 0.9830 - precision: 0.9866 - recall: 0.9850 - sensitivity: 0.9850 - specificity: 0.9973 - val_accuracy: 0.9314 - val_auc: 0.9922 - val_f1_score: 0.9316 - val_loss: 0.2174 - val_mcc: 0.9179 - val_precision: 0.9327 - val_recall: 0.9305 - val_sensitivity: 0.9305 - val_specificity: 0.9866 - learning_rate: 4.5953e-05
# Epoch 22/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 67us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0166 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.9000 - val_auc: 0.9940 - val_f1_score: 0.9000 - val_loss: 0.1946 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 4.4115e-05
# Epoch 23/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 88ms/step - accuracy: 0.9922 - auc: 0.9999 - f1_score: 0.9919 - loss: 0.0298 - mcc: 0.9902 - precision: 0.9924 - recall: 0.9914 - sensitivity: 0.9914 - specificity: 0.9985 - val_accuracy: 0.8826 - val_auc: 0.9746 - val_f1_score: 0.8822 - val_loss: 0.5070 - val_mcc: 0.8588 - val_precision: 0.8874 - val_recall: 0.8770 - val_sensitivity: 0.8770 - val_specificity: 0.9777 - learning_rate: 4.2351e-05
# Epoch 24/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 70us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0049 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.8000 - val_auc: 0.8720 - val_f1_score: 0.8000 - val_loss: 2.5086 - val_mcc: 0.7600 - val_precision: 0.8000 - val_recall: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.9600 - learning_rate: 4.0656e-05
# Epoch 25/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 87ms/step - accuracy: 0.9924 - auc: 1.0000 - f1_score: 0.9924 - loss: 0.0238 - mcc: 0.9909 - precision: 0.9925 - recall: 0.9923 - sensitivity: 0.9923 - specificity: 0.9985 - val_accuracy: 0.9172 - val_auc: 0.9865 - val_f1_score: 0.9176 - val_loss: 0.3168 - val_mcc: 0.9012 - val_precision: 0.9190 - val_recall: 0.9163 - val_sensitivity: 0.9163 - val_specificity: 0.9838 - learning_rate: 3.9030e-05

# %%
execution_time = end_time - start_time

milliseconds = int(execution_time * 1000)
seconds, milliseconds = divmod(milliseconds, 1000)
minutes, seconds = divmod(seconds, 60)
hours, minutes = divmod(minutes, 60)

time_string = f"{hours} hours, " if hours else ""
time_string += f"{minutes} minutes, " if minutes else ""
time_string += f"{seconds} seconds, " if seconds else ""
time_string += f"{milliseconds} milliseconds"

print(f"Model training took {time_string}")
# Out:
# Model training took 18 minutes, 5 seconds, 220 milliseconds

# %%
test_steps = math.ceil(test_generator.samples / test_generator.batch_size)
_ = model.evaluate(test_generator, steps=test_steps)
# Out:
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 40s 129ms/step - accuracy: 0.9310 - auc: 0.9894 - f1_score: 0.9312 - loss: 0.2484 - mcc: 0.9175 - precision: 0.9328 - recall: 0.9296 - sensitivity: 0.9296 - specificity: 0.9866

# %%
def plot_metrics(hist, metric_name_list):
    """
    Plots the given metrics for the training and validation sets.

    Args:
        hist: a Keras History object containing the training history
        metric_name_list: a list of strings representing the names of the metrics to plot

    Returns:
        None
    """
    num_metrics = len(metric_name_list)

    figure, axes = plt.subplots(num_metrics, figsize=(10, 6 * num_metrics))

    rng = range(1, len(hist.history[metric_name_list[0]]) + 1)

    for ax, metric_n in zip(axes, metric_name_list):
        metric = hist.history[metric_n]
        v_metric = hist.history[f"val_{metric_n}"]

        ax.plot(rng, metric, label=metric_n)
        ax.plot(rng, v_metric, label=f"val_{metric_n}")
        ax.legend()
        ax.set_xlabel("Epochs")

        if metric_n in ("auc", "mcc"):
            ax.set_ylabel(metric_n.upper())
            ax.set_title(metric_n.upper() + " vs Epochs")
        else:
            ax.set_ylabel(metric_n.capitalize())
            ax.set_title(metric_n.capitalize() + " vs Epochs")

        max_loss = max(max(metric), max(v_metric))
        min_loss = min(min(metric), min(v_metric))
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()

    plt.show()

# %%
metric_names = ["loss", "accuracy", "precision", "recall", "f1_score",
                "specificity", "sensitivity", "mcc", "auc"]
plot_metrics(history, metric_names)

# %%
def generate_classification_report(model, test_generator, test_steps, batch_size, target_names):
    """
    Generate a classification report, accuracy, and number of errors for a given model and test generator.

    Args:
        model (object): The trained model.
        test_generator (object): The test data generator.
        test_steps (int): The number of steps to iterate over the test generator.
        batch_size (int): The batch size for generating predictions.
        target_names (list): List of target class names for the classification report.

    Returns:
        tuple: A tuple containing true labels, predicted labels, and the classification report.
    """
    predicted_labels = []
    true_labels = []

    for i in range(test_steps):
        batch_data, batch_true_labels = next(test_generator)

        batch_predicted_labels = model.predict_on_batch(batch_data)
        batch_predicted_labels = np.argmax(batch_predicted_labels, axis=1)

        predicted_labels.extend(batch_predicted_labels)
        true_labels.extend(batch_true_labels)

    true_labels = np.array(true_labels)

    if len(true_labels[0]) > 1:
        true_labels = np.argmax(true_labels, axis=1)

    report = classification_report(
        true_labels,
        predicted_labels,
        target_names=target_names,
        digits=4,
        zero_division=1
    )

    accuracy = accuracy_score(true_labels, predicted_labels)
    num_errors = np.sum(true_labels != predicted_labels)

    print(report)
    print(f'There were {num_errors} errors in {len(predicted_labels)} tests for an accuracy of {accuracy*100:6.2f}')

    return true_labels, predicted_labels

# %%
classes = list(train_generator.class_indices.keys())
true_labels, predicted_labels = generate_classification_report(
    model, test_generator, test_steps, BATCH_SIZE, classes
)
# Out:
#                      precision    recall  f1-score   support
#
# Bacterial Pneumonia     0.9456    1.0000    0.9720       556
#               COVID     0.9925    0.9184    0.9540       723
#        Lung_Opacity     0.9422    0.8136    0.8732      1202
#              Normal     0.8775    0.9735    0.9230      2039
#        Tuberculosis     0.9779    0.9500    0.9638       140
#     Viral Pneumonia     0.9873    0.8662    0.9228       269
#
#            accuracy                         0.9229      4929
#           macro avg     0.9538    0.9203    0.9348      4929
#        weighted avg     0.9267    0.9229    0.9221      4929
#
# There were 380 errors in 4929 tests for an accuracy of  92.29

# %%
def confusion_matrix(true_labels, predicted_labels, num_classes):
    """
    Compute the confusion matrix.

    Args:
        true_labels (list or numpy.ndarray): Array-like object of true labels.
        predicted_labels (list or numpy.ndarray): Array-like object of predicted labels.
        num_classes (int): Number of classes.

    Returns:
        numpy.ndarray: Confusion matrix.
    """
    cm = np.zeros((num_classes, num_classes), dtype=int)
    np.add.at(cm, (true_labels, predicted_labels), 1)
    return cm

# %%
cm = confusion_matrix(true_labels, predicted_labels, 6)

classes = list(train_generator.class_indices.keys())

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=classes, yticklabels=classes)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
