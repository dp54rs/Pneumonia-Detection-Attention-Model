# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import keras.backend as K
from time import perf_counter
import matplotlib.pyplot as plt
from keras import layers, models
from keras.utils import plot_model
from keras.metrics import Precision, Recall, AUC
from keras.callbacks import LearningRateScheduler
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load the precomputed folds
df = pd.read_csv('/kaggle/input/exp105-train-5-folds/exp105_train_5_folds.csv')

# Manually choose the fold (e.g., fold 0)
fold = 4
train_df = df[df['fold'] != fold]
val_df   = df[df['fold'] == fold]

IMG_SIZE = 224
BATCH_SIZE = 16

# Initialize image data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen   = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    x_col='filepath',
    y_col='label',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_dataframe(
    val_df,
    x_col='filepath',
    y_col='label',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# This directory remains the same for all folds.
test_dir = '/kaggle/input/pneumonia-imbalance-chest-x-ray-dataset/test'

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Typically, you don't shuffle test data
)
# Out:
# Found 13801 validated image filenames belonging to 6 classes.
# Found 3450 validated image filenames belonging to 6 classes.
# Found 4929 images belonging to 6 classes.

# %%
class NegativeImageLayer(layers.Layer):
    def __init__(self, **kwargs):
        super(NegativeImageLayer, self).__init__(**kwargs)

    def call(self, inputs):
        return tf.negative(inputs)

    def get_config(self):
        config = super(NegativeImageLayer, self).get_config()
        return config

class TwiceMaxMinPooling2D(layers.Layer):
    def __init__(self, pool_size=(2, 2), strides=2, padding="SAME", **kwargs):
        super(TwiceMaxMinPooling2D, self).__init__(**kwargs)
        self.pool_size = pool_size
        self.strides = strides
        self.padding = padding

    def call(self, inputs, *args, **kwargs):
        # Max pooling
        max_pool = tf.keras.layers.MaxPooling2D(
            pool_size=self.pool_size, strides=self.strides, padding=self.padding
        )(inputs)

        # Min pooling
        neg_inputs = -inputs
        neg_max_pool = tf.keras.layers.MaxPooling2D(
            pool_size=self.pool_size, strides=self.strides, padding=self.padding
        )(neg_inputs)
        min_pool = -neg_max_pool

        # Twice max - min
        return 2 * max_pool - min_pool

    def get_config(self):
        config = super().get_config()
        config.update({
            "pool_size": self.pool_size,
            "strides": self.strides,
            "padding": self.padding
        })
        return config

# %%
inputs = layers.Input(shape=(224, 224, 3), name="Input")

# Block 1
x = layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv1")(inputs)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv1")(x)
x = layers.BatchNormalization()(x)
blk1 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool1")(x)

# Block 2
x = layers.Conv2D(64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv2")(blk1)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv2")(x)
x = layers.BatchNormalization()(x)
blk2 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool2")(x)

# Block 3
x = layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv3")(blk2)
x = layers.MaxPooling2D(pool_size=2, strides=2, padding="same", name="MaxPool3")(x)
x = layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv4")(x)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv3")(x)
x = layers.BatchNormalization()(x)
blk3 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool4")(x)

# Block 4
x = layers.Conv2D(256, kernel_size=(3, 3), padding="same", activation="relu", name="Conv5")(blk3)
x = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool5")(x)
x = layers.Conv2D(512, kernel_size=(3, 3), padding="same", activation="relu", name="Conv6")(x)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv4")(x)
blk4 = layers.BatchNormalization()(x)

# Block 5
y = NegativeImageLayer()(blk2)
y = TwiceMaxMinPooling2D(pool_size=(3, 3))(y)
y = layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv7")(y)
y = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool7")(y)
y = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv5")(y) 
y = layers.Conv2D(64, kernel_size=(5, 5), padding="same", activation="relu", name="Conv8")(y)
y = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool8")(y)
y = layers.Conv2D(224, kernel_size=(3, 3), padding="same", activation="relu", name="Conv9")(y)
blk5 = layers.BatchNormalization()(y)


x = layers.Concatenate(name="DirectConcat")([blk4, blk5])

x = layers.GlobalAveragePooling2D(name="GAP")(x)

outputs = layers.Dense(6, activation="softmax", name="Output")(x)

model = models.Model(inputs=inputs, outputs=outputs)

# %%
class CustomMetrics(tf.keras.metrics.Metric):
    def __init__(self, metric_name, **kwargs):
        super(CustomMetrics, self).__init__(name=metric_name, **kwargs)
        self.metric_name = metric_name
        self.tp = self.add_weight(name="tp", initializer="zeros")
        self.tn = self.add_weight(name="tn", initializer="zeros")
        self.fp = self.add_weight(name="fp", initializer="zeros")
        self.fn = self.add_weight(name="fn", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        y_pred = tf.round(tf.clip_by_value(y_pred, 0, 1))
        y_true = tf.round(tf.clip_by_value(y_true, 0, 1))

        self.tp.assign_add(tf.reduce_sum(y_true * y_pred))
        self.tn.assign_add(tf.reduce_sum((1 - y_true) * (1 - y_pred)))
        self.fp.assign_add(tf.reduce_sum((1 - y_true) * y_pred))
        self.fn.assign_add(tf.reduce_sum(y_true * (1 - y_pred)))

    def result(self):
        if self.metric_name == "f1_score":
            precision = self.tp / (self.tp + self.fp + tf.keras.backend.epsilon())
            recall = self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
            return 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
        elif self.metric_name == "specificity":
            return self.tn / (self.tn + self.fp + tf.keras.backend.epsilon())
        elif self.metric_name == "sensitivity":
            return self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
        elif self.metric_name == "mcc":
            numerator = (self.tp * self.tn - self.fp * self.fn)
            denominator = tf.math.sqrt(
                (self.tp + self.fp) * (self.tp + self.fn) *
                (self.tn + self.fp) * (self.tn + self.fn)
            )
            return numerator / (denominator + tf.keras.backend.epsilon())
        else:
            raise ValueError(f"Unknown metric name: {self.metric_name}")

    def reset_states(self):
        self.tp.assign(0)
        self.tn.assign(0)
        self.fp.assign(0)
        self.fn.assign(0)

def create_metrics():
    return [
        Precision(name="precision"),
        Recall(name="recall"),
        CustomMetrics(metric_name="f1_score"),
        CustomMetrics(metric_name="specificity"),
        CustomMetrics(metric_name="sensitivity"),
        CustomMetrics(metric_name="mcc"),
        AUC(name="auc"),
    ]

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'] + create_metrics()
)

# %%
TOTAL_EPOCHS = 25
INITIAL_LEARNING_RATE = 0.75e-4
DECAY_RATE = 0.96

def learning_rate_scheduler(epoch, current_learning_rate):
    """
    A function that returns the learning rate for each epoch.

    Args:
        epoch (int): The current epoch.
        current_learning_rate (float): The current learning rate.

    Returns:
        float: The new learning rate.
    """
    if epoch < (TOTAL_EPOCHS / 3):
        new_learning_rate = INITIAL_LEARNING_RATE
    else:
        new_learning_rate = current_learning_rate * DECAY_RATE

    return new_learning_rate

# %%
learning_rate_callback = LearningRateScheduler(learning_rate_scheduler)

# %%
start_time = perf_counter()
history = model.fit(
    train_generator,
    callbacks=[learning_rate_callback],
    validation_data=val_generator,
    epochs=TOTAL_EPOCHS,
    steps_per_epoch=len(train_df) // BATCH_SIZE,
    validation_steps=len(val_df) // BATCH_SIZE
)
end_time = perf_counter()
# Out:
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 143s 142ms/step - accuracy: 0.6962 - auc: 0.9111 - f1_score: 0.6158 - loss: 0.9174 - mcc: 0.5913 - precision: 0.8155 - recall: 0.5150 - sensitivity: 0.5150 - specificity: 0.9793 - val_accuracy: 0.8297 - val_auc: 0.9760 - val_f1_score: 0.8300 - val_loss: 0.4760 - val_mcc: 0.7985 - val_precision: 0.8643 - val_recall: 0.7983 - val_sensitivity: 0.7983 - val_specificity: 0.9749 - learning_rate: 7.5000e-05
# Epoch 2/25
#   1/862 ━━━━━━━━━━━━━━━━━━━━ 1:01 71ms/step - accuracy: 0.8125 - auc: 0.9539 - f1_score: 0.8125 - loss: 0.7254 - mcc: 0.7750 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.9625
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8125 - auc: 0.9539 - f1_score: 0.8125 - loss: 0.7254 - mcc: 0.7750 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.9625 - val_accuracy: 0.8000 - val_auc: 0.9500 - val_f1_score: 0.7778 - val_loss: 0.6959 - val_mcc: 0.7455 - val_precision: 0.8750 - val_recall: 0.7000 - val_sensitivity: 0.7000 - val_specificity: 0.9800 - learning_rate: 7.5000e-05
# Epoch 3/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 74s 85ms/step - accuracy: 0.8735 - auc: 0.9849 - f1_score: 0.8708 - loss: 0.3708 - mcc: 0.8462 - precision: 0.8936 - recall: 0.8492 - sensitivity: 0.8492 - specificity: 0.9798 - val_accuracy: 0.9023 - val_auc: 0.9912 - val_f1_score: 0.9037 - val_loss: 0.2772 - val_mcc: 0.8848 - val_precision: 0.9141 - val_recall: 0.8936 - val_sensitivity: 0.8936 - val_specificity: 0.9832 - learning_rate: 7.5000e-05
# Epoch 4/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 68us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 0.9677 - loss: 0.1493 - mcc: 0.9623 - precision: 1.0000 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 1.0000 - val_accuracy: 0.9000 - val_auc: 0.9980 - val_f1_score: 0.9000 - val_loss: 0.1333 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 7.5000e-05
# Epoch 5/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.9053 - auc: 0.9917 - f1_score: 0.9047 - loss: 0.2676 - mcc: 0.8860 - precision: 0.9169 - recall: 0.8928 - sensitivity: 0.8928 - specificity: 0.9838 - val_accuracy: 0.8541 - val_auc: 0.9806 - val_f1_score: 0.8554 - val_loss: 0.4171 - val_mcc: 0.8269 - val_precision: 0.8641 - val_recall: 0.8468 - val_sensitivity: 0.8468 - val_specificity: 0.9734 - learning_rate: 7.5000e-05
# Epoch 6/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 70us/step - accuracy: 0.8125 - auc: 0.9805 - f1_score: 0.8125 - loss: 0.4890 - mcc: 0.7750 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.9625 - val_accuracy: 0.6000 - val_auc: 0.9550 - val_f1_score: 0.6667 - val_loss: 0.6528 - val_mcc: 0.6139 - val_precision: 0.7500 - val_recall: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.9600 - learning_rate: 7.5000e-05
# Epoch 7/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9267 - auc: 0.9946 - f1_score: 0.9263 - loss: 0.2119 - mcc: 0.9118 - precision: 0.9330 - recall: 0.9198 - sensitivity: 0.9198 - specificity: 0.9868 - val_accuracy: 0.8910 - val_auc: 0.9894 - val_f1_score: 0.8907 - val_loss: 0.2940 - val_mcc: 0.8692 - val_precision: 0.9000 - val_recall: 0.8817 - val_sensitivity: 0.8817 - val_specificity: 0.9804 - learning_rate: 7.5000e-05
# Epoch 8/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0566 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.8000 - val_auc: 0.9860 - val_f1_score: 0.8000 - val_loss: 0.4743 - val_mcc: 0.7600 - val_precision: 0.8000 - val_recall: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.9600 - learning_rate: 7.5000e-05
# Epoch 9/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 74s 86ms/step - accuracy: 0.9412 - auc: 0.9964 - f1_score: 0.9416 - loss: 0.1696 - mcc: 0.9300 - precision: 0.9468 - recall: 0.9365 - sensitivity: 0.9365 - specificity: 0.9895 - val_accuracy: 0.9151 - val_auc: 0.9919 - val_f1_score: 0.9144 - val_loss: 0.2454 - val_mcc: 0.8973 - val_precision: 0.9175 - val_recall: 0.9113 - val_sensitivity: 0.9113 - val_specificity: 0.9836 - learning_rate: 7.5000e-05
# Epoch 10/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 63us/step - accuracy: 0.9375 - auc: 0.9992 - f1_score: 0.9375 - loss: 0.1029 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.7000 - val_auc: 0.9800 - val_f1_score: 0.7000 - val_loss: 0.4554 - val_mcc: 0.6400 - val_precision: 0.7000 - val_recall: 0.7000 - val_sensitivity: 0.7000 - val_specificity: 0.9400 - learning_rate: 7.2000e-05
# Epoch 11/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.9472 - auc: 0.9967 - f1_score: 0.9459 - loss: 0.1526 - mcc: 0.9352 - precision: 0.9495 - recall: 0.9424 - sensitivity: 0.9424 - specificity: 0.9900 - val_accuracy: 0.6817 - val_auc: 0.9338 - val_f1_score: 0.6816 - val_loss: 0.9638 - val_mcc: 0.6187 - val_precision: 0.6881 - val_recall: 0.6753 - val_sensitivity: 0.6753 - val_specificity: 0.9388 - learning_rate: 6.9120e-05
# Epoch 12/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 0.9677 - loss: 0.0561 - mcc: 0.9623 - precision: 1.0000 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 1.0000 - val_accuracy: 0.8000 - val_auc: 0.9730 - val_f1_score: 0.8000 - val_loss: 0.4766 - val_mcc: 0.7600 - val_precision: 0.8000 - val_recall: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.9600 - learning_rate: 6.6355e-05
# Epoch 13/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9637 - auc: 0.9983 - f1_score: 0.9637 - loss: 0.1111 - mcc: 0.9565 - precision: 0.9655 - recall: 0.9619 - sensitivity: 0.9619 - specificity: 0.9931 - val_accuracy: 0.8485 - val_auc: 0.9695 - val_f1_score: 0.8483 - val_loss: 0.5661 - val_mcc: 0.8180 - val_precision: 0.8506 - val_recall: 0.8459 - val_sensitivity: 0.8459 - val_specificity: 0.9703 - learning_rate: 6.3701e-05
# Epoch 14/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 63us/step - accuracy: 0.9375 - auc: 0.9941 - f1_score: 0.9375 - loss: 0.2637 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.9000 - val_auc: 0.9940 - val_f1_score: 0.9000 - val_loss: 0.2384 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 6.1153e-05
# Epoch 15/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9671 - auc: 0.9987 - f1_score: 0.9670 - loss: 0.1006 - mcc: 0.9605 - precision: 0.9692 - recall: 0.9649 - sensitivity: 0.9649 - specificity: 0.9939 - val_accuracy: 0.9113 - val_auc: 0.9918 - val_f1_score: 0.9106 - val_loss: 0.2591 - val_mcc: 0.8929 - val_precision: 0.9171 - val_recall: 0.9041 - val_sensitivity: 0.9041 - val_specificity: 0.9837 - learning_rate: 5.8707e-05
# Epoch 16/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 62us/step - accuracy: 0.9375 - auc: 0.9961 - f1_score: 0.9375 - loss: 0.1700 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.9000 - val_auc: 0.9920 - val_f1_score: 0.9000 - val_loss: 0.2899 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 5.6359e-05
# Epoch 17/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 74s 86ms/step - accuracy: 0.9744 - auc: 0.9993 - f1_score: 0.9737 - loss: 0.0796 - mcc: 0.9685 - precision: 0.9752 - recall: 0.9723 - sensitivity: 0.9723 - specificity: 0.9950 - val_accuracy: 0.9110 - val_auc: 0.9905 - val_f1_score: 0.9127 - val_loss: 0.2762 - val_mcc: 0.8954 - val_precision: 0.9182 - val_recall: 0.9073 - val_sensitivity: 0.9073 - val_specificity: 0.9838 - learning_rate: 5.4104e-05
# Epoch 18/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 63us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0154 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.9000 - val_auc: 0.9980 - val_f1_score: 0.9000 - val_loss: 0.1792 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 5.1940e-05
# Epoch 19/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9828 - auc: 0.9997 - f1_score: 0.9825 - loss: 0.0560 - mcc: 0.9791 - precision: 0.9837 - recall: 0.9814 - sensitivity: 0.9814 - specificity: 0.9967 - val_accuracy: 0.9157 - val_auc: 0.9890 - val_f1_score: 0.9164 - val_loss: 0.2821 - val_mcc: 0.8997 - val_precision: 0.9180 - val_recall: 0.9148 - val_sensitivity: 0.9148 - val_specificity: 0.9837 - learning_rate: 4.9862e-05
# Epoch 20/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 73us/step - accuracy: 0.9375 - auc: 0.9977 - f1_score: 0.9375 - loss: 0.1305 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.9000 - val_auc: 0.9980 - val_f1_score: 0.9000 - val_loss: 0.0978 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 4.7868e-05
# Epoch 21/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 74s 86ms/step - accuracy: 0.9838 - auc: 0.9997 - f1_score: 0.9840 - loss: 0.0494 - mcc: 0.9808 - precision: 0.9846 - recall: 0.9834 - sensitivity: 0.9834 - specificity: 0.9969 - val_accuracy: 0.9375 - val_auc: 0.9940 - val_f1_score: 0.9378 - val_loss: 0.1888 - val_mcc: 0.9254 - val_precision: 0.9399 - val_recall: 0.9358 - val_sensitivity: 0.9358 - val_specificity: 0.9880 - learning_rate: 4.5953e-05
# Epoch 22/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 68us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0522 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0077 - val_mcc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 4.4115e-05
# Epoch 23/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9908 - auc: 0.9999 - f1_score: 0.9906 - loss: 0.0345 - mcc: 0.9887 - precision: 0.9911 - recall: 0.9901 - sensitivity: 0.9901 - specificity: 0.9982 - val_accuracy: 0.9047 - val_auc: 0.9890 - val_f1_score: 0.9055 - val_loss: 0.2767 - val_mcc: 0.8867 - val_precision: 0.9099 - val_recall: 0.9012 - val_sensitivity: 0.9012 - val_specificity: 0.9822 - learning_rate: 4.2351e-05
# Epoch 24/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0033 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0361 - val_mcc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 4.0656e-05
# Epoch 25/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 74s 85ms/step - accuracy: 0.9950 - auc: 1.0000 - f1_score: 0.9951 - loss: 0.0227 - mcc: 0.9941 - precision: 0.9952 - recall: 0.9949 - sensitivity: 0.9949 - specificity: 0.9990 - val_accuracy: 0.9366 - val_auc: 0.9919 - val_f1_score: 0.9353 - val_loss: 0.2126 - val_mcc: 0.9224 - val_precision: 0.9375 - val_recall: 0.9331 - val_sensitivity: 0.9331 - val_specificity: 0.9876 - learning_rate: 3.9030e-05

# %%
execution_time = end_time - start_time

milliseconds = int(execution_time * 1000)
seconds, milliseconds = divmod(milliseconds, 1000)
minutes, seconds = divmod(seconds, 60)
hours, minutes = divmod(minutes, 60)

time_string = f"{hours} hours, " if hours else ""
time_string += f"{minutes} minutes, " if minutes else ""
time_string += f"{seconds} seconds, " if seconds else ""
time_string += f"{milliseconds} milliseconds"

print(f"Model training took {time_string}")
# Out:
# Model training took 17 minutes, 23 seconds, 145 milliseconds

# %%
test_steps = math.ceil(test_generator.samples / test_generator.batch_size)
_ = model.evaluate(test_generator, steps=test_steps)
# Out:
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 36s 116ms/step - accuracy: 0.9578 - auc: 0.9949 - f1_score: 0.9577 - loss: 0.1414 - mcc: 0.9492 - precision: 0.9583 - recall: 0.9571 - sensitivity: 0.9571 - specificity: 0.9917

# %%
def plot_metrics(hist, metric_name_list):
    """
    Plots the given metrics for the training and validation sets.

    Args:
        hist: a Keras History object containing the training history
        metric_name_list: a list of strings representing the names of the metrics to plot

    Returns:
        None
    """
    num_metrics = len(metric_name_list)

    figure, axes = plt.subplots(num_metrics, figsize=(10, 6 * num_metrics))

    rng = range(1, len(hist.history[metric_name_list[0]]) + 1)

    for ax, metric_n in zip(axes, metric_name_list):
        metric = hist.history[metric_n]
        v_metric = hist.history[f"val_{metric_n}"]

        ax.plot(rng, metric, label=metric_n)
        ax.plot(rng, v_metric, label=f"val_{metric_n}")
        ax.legend()
        ax.set_xlabel("Epochs")

        if metric_n in ("auc", "mcc"):
            ax.set_ylabel(metric_n.upper())
            ax.set_title(metric_n.upper() + " vs Epochs")
        else:
            ax.set_ylabel(metric_n.capitalize())
            ax.set_title(metric_n.capitalize() + " vs Epochs")

        max_loss = max(max(metric), max(v_metric))
        min_loss = min(min(metric), min(v_metric))
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()

    plt.show()

# %%
metric_names = ["loss", "accuracy", "precision", "recall", "f1_score",
                "specificity", "sensitivity", "mcc", "auc"]
plot_metrics(history, metric_names)

# %%
def generate_classification_report(model, test_generator, test_steps, batch_size, target_names):
    """
    Generate a classification report, accuracy, and number of errors for a given model and test generator.

    Args:
        model (object): The trained model.
        test_generator (object): The test data generator.
        test_steps (int): The number of steps to iterate over the test generator.
        batch_size (int): The batch size for generating predictions.
        target_names (list): List of target class names for the classification report.

    Returns:
        tuple: A tuple containing true labels, predicted labels, and the classification report.
    """
    predicted_labels = []
    true_labels = []

    for i in range(test_steps):
        batch_data, batch_true_labels = next(test_generator)

        batch_predicted_labels = model.predict_on_batch(batch_data)
        batch_predicted_labels = np.argmax(batch_predicted_labels, axis=1)

        predicted_labels.extend(batch_predicted_labels)
        true_labels.extend(batch_true_labels)

    true_labels = np.array(true_labels)

    if len(true_labels[0]) > 1:
        true_labels = np.argmax(true_labels, axis=1)

    report = classification_report(
        true_labels,
        predicted_labels,
        target_names=target_names,
        digits=4,
        zero_division=1
    )

    accuracy = accuracy_score(true_labels, predicted_labels)
    num_errors = np.sum(true_labels != predicted_labels)

    print(report)
    print(f'There were {num_errors} errors in {len(predicted_labels)} tests for an accuracy of {accuracy*100:6.2f}')

    return true_labels, predicted_labels

# %%
classes = list(train_generator.class_indices.keys())
true_labels, predicted_labels = generate_classification_report(
    model, test_generator, test_steps, BATCH_SIZE, classes
)
# Out:
#                      precision    recall  f1-score   support
#
# Bacterial Pneumonia     0.9720    1.0000    0.9858       556
#               COVID     0.9644    0.9737    0.9690       723
#        Lung_Opacity     0.9279    0.8777    0.9021      1202
#              Normal     0.9292    0.9524    0.9407      2039
#        Tuberculosis     0.9786    0.9786    0.9786       140
#     Viral Pneumonia     0.9577    0.9257    0.9414       269
#
#            accuracy                         0.9420      4929
#           macro avg     0.9550    0.9513    0.9529      4929
#        weighted avg     0.9418    0.9420    0.9416      4929
#
# There were 286 errors in 4929 tests for an accuracy of  94.20

# %%
def confusion_matrix(true_labels, predicted_labels, num_classes):
    """
    Compute the confusion matrix.

    Args:
        true_labels (list or numpy.ndarray): Array-like object of true labels.
        predicted_labels (list or numpy.ndarray): Array-like object of predicted labels.
        num_classes (int): Number of classes.

    Returns:
        numpy.ndarray: Confusion matrix.
    """
    cm = np.zeros((num_classes, num_classes), dtype=int)
    np.add.at(cm, (true_labels, predicted_labels), 1)
    return cm

# %%
cm = confusion_matrix(true_labels, predicted_labels, 6)

classes = list(train_generator.class_indices.keys())

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=classes, yticklabels=classes)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
