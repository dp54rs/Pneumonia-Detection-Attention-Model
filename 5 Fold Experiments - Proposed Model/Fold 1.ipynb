# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import keras.backend as K
from time import perf_counter
import matplotlib.pyplot as plt
from keras import layers, models
from keras.utils import plot_model
from keras.metrics import Precision, Recall, AUC
from keras.callbacks import LearningRateScheduler
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load the precomputed folds
df = pd.read_csv('/kaggle/input/exp105-train-5-folds/exp105_train_5_folds.csv')

# Manually choose the fold (e.g., fold 0)
fold = 0
train_df = df[df['fold'] != fold]
val_df   = df[df['fold'] == fold]

IMG_SIZE = 224
BATCH_SIZE = 16

# Initialize image data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen   = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    x_col='filepath',
    y_col='label',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_dataframe(
    val_df,
    x_col='filepath',
    y_col='label',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# This directory remains the same for all folds.
test_dir = '/kaggle/input/pneumonia-imbalance-chest-x-ray-dataset/test'

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Typically, you don't shuffle test data
)
# Out:
# Found 13800 validated image filenames belonging to 6 classes.
# Found 3451 validated image filenames belonging to 6 classes.
# Found 4929 images belonging to 6 classes.

# %%
class NegativeImageLayer(layers.Layer):
    def __init__(self, **kwargs):
        super(NegativeImageLayer, self).__init__(**kwargs)

    def call(self, inputs):
        return tf.negative(inputs)

    def get_config(self):
        config = super(NegativeImageLayer, self).get_config()
        return config

class TwiceMaxMinPooling2D(layers.Layer):
    def __init__(self, pool_size=(2, 2), strides=2, padding="SAME", **kwargs):
        super(TwiceMaxMinPooling2D, self).__init__(**kwargs)
        self.pool_size = pool_size
        self.strides = strides
        self.padding = padding

    def call(self, inputs, *args, **kwargs):
        # Max pooling
        max_pool = tf.keras.layers.MaxPooling2D(
            pool_size=self.pool_size, strides=self.strides, padding=self.padding
        )(inputs)

        # Min pooling
        neg_inputs = -inputs
        neg_max_pool = tf.keras.layers.MaxPooling2D(
            pool_size=self.pool_size, strides=self.strides, padding=self.padding
        )(neg_inputs)
        min_pool = -neg_max_pool

        # Twice max - min
        return 2 * max_pool - min_pool

    def get_config(self):
        config = super().get_config()
        config.update({
            "pool_size": self.pool_size,
            "strides": self.strides,
            "padding": self.padding
        })
        return config

# %%
inputs = layers.Input(shape=(224, 224, 3), name="Input")

# Block 1
x = layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv1")(inputs)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv1")(x)
x = layers.BatchNormalization()(x)
blk1 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool1")(x)

# Block 2
x = layers.Conv2D(64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv2")(blk1)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv2")(x)
x = layers.BatchNormalization()(x)
blk2 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool2")(x)

# Block 3
x = layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv3")(blk2)
x = layers.MaxPooling2D(pool_size=2, strides=2, padding="same", name="MaxPool3")(x)
x = layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv4")(x)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv3")(x)
x = layers.BatchNormalization()(x)
blk3 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool4")(x)

# Block 4
x = layers.Conv2D(256, kernel_size=(3, 3), padding="same", activation="relu", name="Conv5")(blk3)
x = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool5")(x)
x = layers.Conv2D(512, kernel_size=(3, 3), padding="same", activation="relu", name="Conv6")(x)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv4")(x)
blk4 = layers.BatchNormalization()(x)

# Block 5
y = NegativeImageLayer()(blk2)
y = TwiceMaxMinPooling2D(pool_size=(3, 3))(y)
y = layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv7")(y)
y = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool7")(y)
y = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv5")(y) 
y = layers.Conv2D(64, kernel_size=(5, 5), padding="same", activation="relu", name="Conv8")(y)
y = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool8")(y)
y = layers.Conv2D(224, kernel_size=(3, 3), padding="same", activation="relu", name="Conv9")(y)
blk5 = layers.BatchNormalization()(y)


x = layers.Concatenate(name="DirectConcat")([blk4, blk5])

x = layers.GlobalAveragePooling2D(name="GAP")(x)

outputs = layers.Dense(6, activation="softmax", name="Output")(x)

model = models.Model(inputs=inputs, outputs=outputs)

# %%
class CustomMetrics(tf.keras.metrics.Metric):
    def __init__(self, metric_name, **kwargs):
        super(CustomMetrics, self).__init__(name=metric_name, **kwargs)
        self.metric_name = metric_name
        self.tp = self.add_weight(name="tp", initializer="zeros")
        self.tn = self.add_weight(name="tn", initializer="zeros")
        self.fp = self.add_weight(name="fp", initializer="zeros")
        self.fn = self.add_weight(name="fn", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        y_pred = tf.round(tf.clip_by_value(y_pred, 0, 1))
        y_true = tf.round(tf.clip_by_value(y_true, 0, 1))

        self.tp.assign_add(tf.reduce_sum(y_true * y_pred))
        self.tn.assign_add(tf.reduce_sum((1 - y_true) * (1 - y_pred)))
        self.fp.assign_add(tf.reduce_sum((1 - y_true) * y_pred))
        self.fn.assign_add(tf.reduce_sum(y_true * (1 - y_pred)))

    def result(self):
        if self.metric_name == "f1_score":
            precision = self.tp / (self.tp + self.fp + tf.keras.backend.epsilon())
            recall = self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
            return 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
        elif self.metric_name == "specificity":
            return self.tn / (self.tn + self.fp + tf.keras.backend.epsilon())
        elif self.metric_name == "sensitivity":
            return self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
        elif self.metric_name == "mcc":
            numerator = (self.tp * self.tn - self.fp * self.fn)
            denominator = tf.math.sqrt(
                (self.tp + self.fp) * (self.tp + self.fn) *
                (self.tn + self.fp) * (self.tn + self.fn)
            )
            return numerator / (denominator + tf.keras.backend.epsilon())
        else:
            raise ValueError(f"Unknown metric name: {self.metric_name}")

    def reset_states(self):
        self.tp.assign(0)
        self.tn.assign(0)
        self.fp.assign(0)
        self.fn.assign(0)

def create_metrics():
    return [
        Precision(name="precision"),
        Recall(name="recall"),
        CustomMetrics(metric_name="f1_score"),
        CustomMetrics(metric_name="specificity"),
        CustomMetrics(metric_name="sensitivity"),
        CustomMetrics(metric_name="mcc"),
        AUC(name="auc"),
    ]

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'] + create_metrics()
)

# %%
TOTAL_EPOCHS = 25
INITIAL_LEARNING_RATE = 0.75e-4
DECAY_RATE = 0.96

def learning_rate_scheduler(epoch, current_learning_rate):
    """
    A function that returns the learning rate for each epoch.

    Args:
        epoch (int): The current epoch.
        current_learning_rate (float): The current learning rate.

    Returns:
        float: The new learning rate.
    """
    if epoch < (TOTAL_EPOCHS / 3):
        new_learning_rate = INITIAL_LEARNING_RATE
    else:
        new_learning_rate = current_learning_rate * DECAY_RATE

    return new_learning_rate

# %%
learning_rate_callback = LearningRateScheduler(learning_rate_scheduler)

# %%
start_time = perf_counter()
history = model.fit(
    train_generator,
    callbacks=[learning_rate_callback],
    validation_data=val_generator,
    epochs=TOTAL_EPOCHS,
    steps_per_epoch=len(train_df) // BATCH_SIZE,
    validation_steps=len(val_df) // BATCH_SIZE
)
end_time = perf_counter()
# Out:
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 200s 208ms/step - accuracy: 0.6954 - auc: 0.9101 - f1_score: 0.6116 - loss: 0.9230 - mcc: 0.5870 - precision: 0.8054 - recall: 0.5099 - sensitivity: 0.5099 - specificity: 0.9797 - val_accuracy: 0.5468 - val_auc: 0.8380 - val_f1_score: 0.5232 - val_loss: 1.4704 - val_mcc: 0.4407 - val_precision: 0.5760 - val_recall: 0.4794 - val_sensitivity: 0.4794 - val_specificity: 0.9294 - learning_rate: 7.5000e-05
# Epoch 2/25
#   1/862 ━━━━━━━━━━━━━━━━━━━━ 1:01 71ms/step - accuracy: 0.9375 - auc: 0.9930 - f1_score: 0.9375 - loss: 0.2168 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9375 - auc: 0.9930 - f1_score: 0.9375 - loss: 0.2168 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.5455 - val_auc: 0.8215 - val_f1_score: 0.5714 - val_loss: 1.6041 - val_mcc: 0.4914 - val_precision: 0.6000 - val_recall: 0.5455 - val_sensitivity: 0.5455 - val_specificity: 0.9273 - learning_rate: 7.5000e-05
# Epoch 3/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.8779 - auc: 0.9862 - f1_score: 0.8746 - loss: 0.3555 - mcc: 0.8505 - precision: 0.8951 - recall: 0.8551 - sensitivity: 0.8551 - specificity: 0.9800 - val_accuracy: 0.8817 - val_auc: 0.9856 - val_f1_score: 0.8807 - val_loss: 0.3506 - val_mcc: 0.8574 - val_precision: 0.8935 - val_recall: 0.8683 - val_sensitivity: 0.8683 - val_specificity: 0.9793 - learning_rate: 7.5000e-05
# Epoch 4/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 71us/step - accuracy: 0.6875 - auc: 0.9621 - f1_score: 0.7097 - loss: 0.5952 - mcc: 0.6543 - precision: 0.7333 - recall: 0.6875 - sensitivity: 0.6875 - specificity: 0.9500 - val_accuracy: 0.8182 - val_auc: 0.9769 - val_f1_score: 0.8182 - val_loss: 0.5497 - val_mcc: 0.7818 - val_precision: 0.8182 - val_recall: 0.8182 - val_sensitivity: 0.8182 - val_specificity: 0.9636 - learning_rate: 7.5000e-05
# Epoch 5/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 87ms/step - accuracy: 0.9054 - auc: 0.9923 - f1_score: 0.9044 - loss: 0.2645 - mcc: 0.8858 - precision: 0.9177 - recall: 0.8915 - sensitivity: 0.8915 - specificity: 0.9840 - val_accuracy: 0.8573 - val_auc: 0.9812 - val_f1_score: 0.8584 - val_loss: 0.4054 - val_mcc: 0.8305 - val_precision: 0.8667 - val_recall: 0.8503 - val_sensitivity: 0.8503 - val_specificity: 0.9738 - learning_rate: 7.5000e-05
# Epoch 6/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - accuracy: 0.8125 - auc: 0.9855 - f1_score: 0.8387 - loss: 0.3814 - mcc: 0.8083 - precision: 0.8667 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.9750 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0174 - val_mcc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 7.5000e-05
# Epoch 7/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 87ms/step - accuracy: 0.9297 - auc: 0.9953 - f1_score: 0.9290 - loss: 0.1981 - mcc: 0.9149 - precision: 0.9354 - recall: 0.9226 - sensitivity: 0.9226 - specificity: 0.9873 - val_accuracy: 0.8631 - val_auc: 0.9823 - val_f1_score: 0.8642 - val_loss: 0.3933 - val_mcc: 0.8374 - val_precision: 0.8721 - val_recall: 0.8564 - val_sensitivity: 0.8564 - val_specificity: 0.9749 - learning_rate: 7.5000e-05
# Epoch 8/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 67us/step - accuracy: 0.9375 - auc: 0.9977 - f1_score: 0.9375 - loss: 0.1430 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0411 - val_mcc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 7.5000e-05
# Epoch 9/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.9365 - auc: 0.9965 - f1_score: 0.9365 - loss: 0.1718 - mcc: 0.9238 - precision: 0.9399 - recall: 0.9331 - sensitivity: 0.9331 - specificity: 0.9881 - val_accuracy: 0.9000 - val_auc: 0.9833 - val_f1_score: 0.8996 - val_loss: 0.3630 - val_mcc: 0.8796 - val_precision: 0.9035 - val_recall: 0.8956 - val_sensitivity: 0.8956 - val_specificity: 0.9809 - learning_rate: 7.5000e-05
# Epoch 10/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 71us/step - accuracy: 0.9375 - auc: 0.9984 - f1_score: 0.9032 - loss: 0.1436 - mcc: 0.8853 - precision: 0.9333 - recall: 0.8750 - sensitivity: 0.8750 - specificity: 0.9875 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0205 - val_mcc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 7.2000e-05
# Epoch 11/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 88ms/step - accuracy: 0.9476 - auc: 0.9976 - f1_score: 0.9477 - loss: 0.1434 - mcc: 0.9373 - precision: 0.9507 - recall: 0.9447 - sensitivity: 0.9447 - specificity: 0.9902 - val_accuracy: 0.8703 - val_auc: 0.9824 - val_f1_score: 0.8708 - val_loss: 0.4179 - val_mcc: 0.8452 - val_precision: 0.8754 - val_recall: 0.8663 - val_sensitivity: 0.8663 - val_specificity: 0.9753 - learning_rate: 6.9120e-05
# Epoch 12/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 68us/step - accuracy: 0.9375 - auc: 0.9977 - f1_score: 0.9375 - loss: 0.1673 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.6364 - val_auc: 0.9355 - val_f1_score: 0.6364 - val_loss: 0.9411 - val_mcc: 0.5636 - val_precision: 0.6364 - val_recall: 0.6364 - val_sensitivity: 0.6364 - val_specificity: 0.9273 - learning_rate: 6.6355e-05
# Epoch 13/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.9583 - auc: 0.9983 - f1_score: 0.9585 - loss: 0.1173 - mcc: 0.9502 - precision: 0.9604 - recall: 0.9567 - sensitivity: 0.9567 - specificity: 0.9921 - val_accuracy: 0.7785 - val_auc: 0.9621 - val_f1_score: 0.7779 - val_loss: 0.6194 - val_mcc: 0.7354 - val_precision: 0.8004 - val_recall: 0.7567 - val_sensitivity: 0.7567 - val_specificity: 0.9623 - learning_rate: 6.3701e-05
# Epoch 14/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 67us/step - accuracy: 0.9375 - auc: 0.9992 - f1_score: 0.9375 - loss: 0.1211 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.9091 - val_auc: 0.9967 - val_f1_score: 0.8571 - val_loss: 0.3545 - val_mcc: 0.8315 - val_precision: 0.9000 - val_recall: 0.8182 - val_sensitivity: 0.8182 - val_specificity: 0.9818 - learning_rate: 6.1153e-05
# Epoch 15/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.9718 - auc: 0.9992 - f1_score: 0.9717 - loss: 0.0846 - mcc: 0.9660 - precision: 0.9735 - recall: 0.9699 - sensitivity: 0.9699 - specificity: 0.9947 - val_accuracy: 0.8724 - val_auc: 0.9781 - val_f1_score: 0.8705 - val_loss: 0.4192 - val_mcc: 0.8449 - val_precision: 0.8786 - val_recall: 0.8625 - val_sensitivity: 0.8625 - val_specificity: 0.9762 - learning_rate: 5.8707e-05
# Epoch 16/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 67us/step - accuracy: 0.8125 - auc: 0.9902 - f1_score: 0.8125 - loss: 0.3285 - mcc: 0.7750 - precision: 0.8125 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.9625 - val_accuracy: 0.9091 - val_auc: 0.9702 - val_f1_score: 0.9091 - val_loss: 0.5218 - val_mcc: 0.8909 - val_precision: 0.9091 - val_recall: 0.9091 - val_sensitivity: 0.9091 - val_specificity: 0.9818 - learning_rate: 5.6359e-05
# Epoch 17/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.9757 - auc: 0.9994 - f1_score: 0.9754 - loss: 0.0724 - mcc: 0.9705 - precision: 0.9765 - recall: 0.9744 - sensitivity: 0.9744 - specificity: 0.9953 - val_accuracy: 0.8680 - val_auc: 0.9705 - val_f1_score: 0.8668 - val_loss: 0.5450 - val_mcc: 0.8405 - val_precision: 0.8750 - val_recall: 0.8587 - val_sensitivity: 0.8587 - val_specificity: 0.9755 - learning_rate: 5.4104e-05
# Epoch 18/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 70us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0435 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.7273 - val_auc: 0.9165 - val_f1_score: 0.7619 - val_loss: 1.3646 - val_mcc: 0.7181 - val_precision: 0.8000 - val_recall: 0.7273 - val_sensitivity: 0.7273 - val_specificity: 0.9636 - learning_rate: 5.1940e-05
# Epoch 19/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 88ms/step - accuracy: 0.9845 - auc: 0.9998 - f1_score: 0.9844 - loss: 0.0458 - mcc: 0.9813 - precision: 0.9849 - recall: 0.9839 - sensitivity: 0.9839 - specificity: 0.9970 - val_accuracy: 0.9186 - val_auc: 0.9901 - val_f1_score: 0.9183 - val_loss: 0.2605 - val_mcc: 0.9020 - val_precision: 0.9220 - val_recall: 0.9145 - val_sensitivity: 0.9145 - val_specificity: 0.9845 - learning_rate: 4.9862e-05
# Epoch 20/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 66us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0094 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.9091 - val_auc: 0.9983 - val_f1_score: 0.9091 - val_loss: 0.1902 - val_mcc: 0.8909 - val_precision: 0.9091 - val_recall: 0.9091 - val_sensitivity: 0.9091 - val_specificity: 0.9818 - learning_rate: 4.7868e-05
# Epoch 21/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9889 - auc: 0.9998 - f1_score: 0.9887 - loss: 0.0383 - mcc: 0.9864 - precision: 0.9894 - recall: 0.9880 - sensitivity: 0.9880 - specificity: 0.9979 - val_accuracy: 0.9299 - val_auc: 0.9902 - val_f1_score: 0.9304 - val_loss: 0.2387 - val_mcc: 0.9165 - val_precision: 0.9325 - val_recall: 0.9282 - val_sensitivity: 0.9282 - val_specificity: 0.9866 - learning_rate: 4.5953e-05
# Epoch 22/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 63us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0097 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.9091 - val_auc: 0.9983 - val_f1_score: 0.9091 - val_loss: 0.1304 - val_mcc: 0.8909 - val_precision: 0.9091 - val_recall: 0.9091 - val_sensitivity: 0.9091 - val_specificity: 0.9818 - learning_rate: 4.4115e-05
# Epoch 23/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 87ms/step - accuracy: 0.9929 - auc: 0.9997 - f1_score: 0.9925 - loss: 0.0295 - mcc: 0.9910 - precision: 0.9930 - recall: 0.9921 - sensitivity: 0.9921 - specificity: 0.9986 - val_accuracy: 0.3407 - val_auc: 0.7667 - val_f1_score: 0.3373 - val_loss: 3.0910 - val_mcc: 0.2062 - val_precision: 0.3403 - val_recall: 0.3343 - val_sensitivity: 0.3343 - val_specificity: 0.8704 - learning_rate: 4.2351e-05
# Epoch 24/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 68us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0599 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.3636 - val_auc: 0.8116 - val_f1_score: 0.3636 - val_loss: 2.3514 - val_mcc: 0.2364 - val_precision: 0.3636 - val_recall: 0.3636 - val_sensitivity: 0.3636 - val_specificity: 0.8727 - learning_rate: 4.0656e-05
# Epoch 25/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 76s 87ms/step - accuracy: 0.9933 - auc: 0.9999 - f1_score: 0.9932 - loss: 0.0224 - mcc: 0.9918 - precision: 0.9934 - recall: 0.9929 - sensitivity: 0.9929 - specificity: 0.9987 - val_accuracy: 0.9169 - val_auc: 0.9818 - val_f1_score: 0.9166 - val_loss: 0.3749 - val_mcc: 0.9000 - val_precision: 0.9178 - val_recall: 0.9154 - val_sensitivity: 0.9154 - val_specificity: 0.9836 - learning_rate: 3.9030e-05

# %%
execution_time = end_time - start_time

milliseconds = int(execution_time * 1000)
seconds, milliseconds = divmod(milliseconds, 1000)
minutes, seconds = divmod(seconds, 60)
hours, minutes = divmod(minutes, 60)

time_string = f"{hours} hours, " if hours else ""
time_string += f"{minutes} minutes, " if minutes else ""
time_string += f"{seconds} seconds, " if seconds else ""
time_string += f"{milliseconds} milliseconds"

print(f"Model training took {time_string}")
# Out:
# Model training took 18 minutes, 32 seconds, 272 milliseconds

# %%
test_steps = math.ceil(test_generator.samples / test_generator.batch_size)
_ = model.evaluate(test_generator, steps=test_steps)
# Out:
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 47s 153ms/step - accuracy: 0.9261 - auc: 0.9828 - f1_score: 0.9263 - loss: 0.3468 - mcc: 0.9115 - precision: 0.9265 - recall: 0.9260 - sensitivity: 0.9260 - specificity: 0.9853

# %%
def plot_metrics(hist, metric_name_list):
    """
    Plots the given metrics for the training and validation sets.

    Args:
        hist: a Keras History object containing the training history
        metric_name_list: a list of strings representing the names of the metrics to plot

    Returns:
        None
    """
    num_metrics = len(metric_name_list)

    figure, axes = plt.subplots(num_metrics, figsize=(10, 6 * num_metrics))

    rng = range(1, len(hist.history[metric_name_list[0]]) + 1)

    for ax, metric_n in zip(axes, metric_name_list):
        metric = hist.history[metric_n]
        v_metric = hist.history[f"val_{metric_n}"]

        ax.plot(rng, metric, label=metric_n)
        ax.plot(rng, v_metric, label=f"val_{metric_n}")
        ax.legend()
        ax.set_xlabel("Epochs")

        if metric_n in ("auc", "mcc"):
            ax.set_ylabel(metric_n.upper())
            ax.set_title(metric_n.upper() + " vs Epochs")
        else:
            ax.set_ylabel(metric_n.capitalize())
            ax.set_title(metric_n.capitalize() + " vs Epochs")

        max_loss = max(max(metric), max(v_metric))
        min_loss = min(min(metric), min(v_metric))
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()

    plt.show()

# %%
metric_names = ["loss", "accuracy", "precision", "recall", "f1_score",
                "specificity", "sensitivity", "mcc", "auc"]
plot_metrics(history, metric_names)

# %%
def generate_classification_report(model, test_generator, test_steps, batch_size, target_names):
    """
    Generate a classification report, accuracy, and number of errors for a given model and test generator.

    Args:
        model (object): The trained model.
        test_generator (object): The test data generator.
        test_steps (int): The number of steps to iterate over the test generator.
        batch_size (int): The batch size for generating predictions.
        target_names (list): List of target class names for the classification report.

    Returns:
        tuple: A tuple containing true labels, predicted labels, and the classification report.
    """
    predicted_labels = []
    true_labels = []

    for i in range(test_steps):
        batch_data, batch_true_labels = next(test_generator)

        batch_predicted_labels = model.predict_on_batch(batch_data)
        batch_predicted_labels = np.argmax(batch_predicted_labels, axis=1)

        predicted_labels.extend(batch_predicted_labels)
        true_labels.extend(batch_true_labels)

    true_labels = np.array(true_labels)

    if len(true_labels[0]) > 1:
        true_labels = np.argmax(true_labels, axis=1)

    report = classification_report(
        true_labels,
        predicted_labels,
        target_names=target_names,
        digits=4,
        zero_division=1
    )

    accuracy = accuracy_score(true_labels, predicted_labels)
    num_errors = np.sum(true_labels != predicted_labels)

    print(report)
    print(f'There were {num_errors} errors in {len(predicted_labels)} tests for an accuracy of {accuracy*100:6.2f}')

    return true_labels, predicted_labels

# %%
classes = list(train_generator.class_indices.keys())
true_labels, predicted_labels = generate_classification_report(
    model, test_generator, test_steps, BATCH_SIZE, classes
)
# Out:
#                      precision    recall  f1-score   support
#
# Bacterial Pneumonia     1.0000    0.9820    0.9909       556
#               COVID     0.9817    0.9627    0.9721       723
#        Lung_Opacity     0.9766    0.7637    0.8571      1202
#              Normal     0.8714    0.9868    0.9255      2039
#        Tuberculosis     0.9857    0.9857    0.9857       140
#     Viral Pneumonia     0.9298    0.9851    0.9567       269
#
#            accuracy                         0.9282      4929
#           macro avg     0.9575    0.9443    0.9480      4929
#        weighted avg     0.9342    0.9282    0.9264      4929
#
# There were 354 errors in 4929 tests for an accuracy of  92.82

# %%
def confusion_matrix(true_labels, predicted_labels, num_classes):
    """
    Compute the confusion matrix.

    Args:
        true_labels (list or numpy.ndarray): Array-like object of true labels.
        predicted_labels (list or numpy.ndarray): Array-like object of predicted labels.
        num_classes (int): Number of classes.

    Returns:
        numpy.ndarray: Confusion matrix.
    """
    cm = np.zeros((num_classes, num_classes), dtype=int)
    np.add.at(cm, (true_labels, predicted_labels), 1)
    return cm

# %%
cm = confusion_matrix(true_labels, predicted_labels, 6)

classes = list(train_generator.class_indices.keys())

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=classes, yticklabels=classes)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
