# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from time import perf_counter
import matplotlib.pyplot as plt
from keras import layers, models
from keras.metrics import Precision, Recall, AUC
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
df = pd.read_csv('/kaggle/input/pneumonia-5-folds/train_folds.csv')

fold = 4
train_df = df[df['fold'] != fold]
val_df   = df[df['fold'] == fold]

IMG_SIZE = 224
BATCH_SIZE = 16

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen   = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    x_col='filepath',
    y_col='label',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_dataframe(
    val_df,
    x_col='filepath',
    y_col='label',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_dir = '/kaggle/input/pneumonia-imbalance-chest-x-ray-dataset/test'

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False 
)
# Out:
# Found 13801 validated image filenames belonging to 6 classes.
# Found 3450 validated image filenames belonging to 6 classes.
# Found 4929 images belonging to 6 classes.

# %%
class NegativeImageLayer(layers.Layer):
    def __init__(self, **kwargs):
        super(NegativeImageLayer, self).__init__(**kwargs)

    def call(self, inputs):
        return tf.negative(inputs)

    def get_config(self):
        config = super(NegativeImageLayer, self).get_config()
        return config

class TwiceMaxMinPooling2D(layers.Layer):
    def __init__(self, pool_size=(2, 2), strides=2, padding="SAME", **kwargs):
        super(TwiceMaxMinPooling2D, self).__init__(**kwargs)
        self.pool_size = pool_size
        self.strides = strides
        self.padding = padding

    def call(self, inputs, *args, **kwargs):
        max_pool = tf.keras.layers.MaxPooling2D(
            pool_size=self.pool_size, strides=self.strides, padding=self.padding
        )(inputs)

        neg_inputs = -inputs
        neg_max_pool = tf.keras.layers.MaxPooling2D(
            pool_size=self.pool_size, strides=self.strides, padding=self.padding
        )(neg_inputs)
        min_pool = -neg_max_pool

        return 2 * max_pool - min_pool

    def get_config(self):
        config = super().get_config()
        config.update({
            "pool_size": self.pool_size,
            "strides": self.strides,
            "padding": self.padding
        })
        return config

# %%
inputs = layers.Input(shape=(224, 224, 3), name="Input")

# Block 1
x = layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv1")(inputs)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv1")(x)
x = layers.BatchNormalization()(x)
blk1 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool1")(x)

# Block 2
x = layers.Conv2D(64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv2")(blk1)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv2")(x)
x = layers.BatchNormalization()(x)
blk2 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool2")(x)

# Block 3
x = layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv3")(blk2)
x = layers.MaxPooling2D(pool_size=2, strides=2, padding="same", name="MaxPool3")(x)
x = layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv4")(x)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv3")(x)
x = layers.BatchNormalization()(x)
blk3 = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool4")(x)

# Block 4
x = layers.Conv2D(256, kernel_size=(3, 3), padding="same", activation="relu", name="Conv5")(blk3)
x = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool5")(x)
x = layers.Conv2D(512, kernel_size=(3, 3), padding="same", activation="relu", name="Conv6")(x)
x = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv4")(x)
blk4 = layers.BatchNormalization()(x)

# Block 5
y = NegativeImageLayer()(blk2)
y = TwiceMaxMinPooling2D(pool_size=(3, 3))(y)
y = layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv7")(y)
y = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool7")(y)
y = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding="same", activation="relu", name="DConv5")(y) 
y = layers.Conv2D(64, kernel_size=(5, 5), padding="same", activation="relu", name="Conv8")(y)
y = layers.MaxPooling2D(pool_size=2, strides=2, name="MaxPool8")(y)
y = layers.Conv2D(224, kernel_size=(3, 3), padding="same", activation="relu", name="Conv9")(y)
blk5 = layers.BatchNormalization()(y)


x = layers.Concatenate(name="DirectConcat")([blk4, blk5])

x = layers.GlobalAveragePooling2D(name="GAP")(x)

outputs = layers.Dense(6, activation="softmax", name="Output")(x)

model = models.Model(inputs=inputs, outputs=outputs)

# %%
class CustomMetrics(tf.keras.metrics.Metric):
    def __init__(self, metric_name, **kwargs):
        super(CustomMetrics, self).__init__(name=metric_name, **kwargs)
        self.metric_name = metric_name
        self.tp = self.add_weight(name="tp", initializer="zeros")
        self.tn = self.add_weight(name="tn", initializer="zeros")
        self.fp = self.add_weight(name="fp", initializer="zeros")
        self.fn = self.add_weight(name="fn", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        y_pred = tf.round(tf.clip_by_value(y_pred, 0, 1))
        y_true = tf.round(tf.clip_by_value(y_true, 0, 1))

        self.tp.assign_add(tf.reduce_sum(y_true * y_pred))
        self.tn.assign_add(tf.reduce_sum((1 - y_true) * (1 - y_pred)))
        self.fp.assign_add(tf.reduce_sum((1 - y_true) * y_pred))
        self.fn.assign_add(tf.reduce_sum(y_true * (1 - y_pred)))

    def result(self):
        if self.metric_name == "f1_score":
            precision = self.tp / (self.tp + self.fp + tf.keras.backend.epsilon())
            recall = self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
            return 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
        elif self.metric_name == "specificity":
            return self.tn / (self.tn + self.fp + tf.keras.backend.epsilon())
        elif self.metric_name == "sensitivity":
            return self.tp / (self.tp + self.fn + tf.keras.backend.epsilon())
        elif self.metric_name == "mcc":
            numerator = (self.tp * self.tn - self.fp * self.fn)
            denominator = tf.math.sqrt(
                (self.tp + self.fp) * (self.tp + self.fn) *
                (self.tn + self.fp) * (self.tn + self.fn)
            )
            return numerator / (denominator + tf.keras.backend.epsilon())
        else:
            raise ValueError(f"Unknown metric name: {self.metric_name}")

    def reset_states(self):
        self.tp.assign(0)
        self.tn.assign(0)
        self.fp.assign(0)
        self.fn.assign(0)

def create_metrics():
    return [
        Precision(name="precision"),
        Recall(name="recall"),
        CustomMetrics(metric_name="f1_score"),
        CustomMetrics(metric_name="specificity"),
        CustomMetrics(metric_name="sensitivity"),
        CustomMetrics(metric_name="mcc"),
        AUC(name="auc"),
    ]

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'] + create_metrics()
)

# %%
TOTAL_EPOCHS = 25
INITIAL_LEARNING_RATE = 0.75e-4
DECAY_RATE = 0.96

def learning_rate_scheduler(epoch, current_learning_rate):
    if epoch < (TOTAL_EPOCHS / 3):
        new_learning_rate = INITIAL_LEARNING_RATE
    else:
        new_learning_rate = current_learning_rate * DECAY_RATE

    return new_learning_rate

# %%
learning_rate_callback = LearningRateScheduler(learning_rate_scheduler)

# %%
start_time = perf_counter()
history = model.fit(
    train_generator,
    callbacks=[learning_rate_callback],
    validation_data=val_generator,
    epochs=TOTAL_EPOCHS,
    steps_per_epoch=len(train_df) // BATCH_SIZE,
    validation_steps=len(val_df) // BATCH_SIZE
)
end_time = perf_counter()
# Out:
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 132s 129ms/step - accuracy: 0.6982 - auc: 0.9095 - f1_score: 0.6098 - loss: 0.9252 - mcc: 0.5881 - precision: 0.8139 - recall: 0.5081 - sensitivity: 0.5081 - specificity: 0.9809 - val_accuracy: 0.7997 - val_auc: 0.9694 - val_f1_score: 0.8019 - val_loss: 0.5444 - val_mcc: 0.7664 - val_precision: 0.8477 - val_recall: 0.7608 - val_sensitivity: 0.7608 - val_specificity: 0.9727 - learning_rate: 7.5000e-05
# Epoch 2/25
#   1/862 ━━━━━━━━━━━━━━━━━━━━ 1:02 72ms/step - accuracy: 0.8750 - auc: 0.9473 - f1_score: 0.8387 - loss: 0.5405 - mcc: 0.8083 - precision: 0.8667 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.9750
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8750 - auc: 0.9473 - f1_score: 0.8387 - loss: 0.5405 - mcc: 0.8083 - precision: 0.8667 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.9750 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 0.8889 - val_loss: 0.2989 - val_mcc: 0.8771 - val_precision: 1.0000 - val_recall: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 1.0000 - learning_rate: 7.5000e-05
# Epoch 3/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.8757 - auc: 0.9852 - f1_score: 0.8721 - loss: 0.3662 - mcc: 0.8478 - precision: 0.8967 - recall: 0.8489 - sensitivity: 0.8489 - specificity: 0.9804 - val_accuracy: 0.8657 - val_auc: 0.9840 - val_f1_score: 0.8632 - val_loss: 0.3819 - val_mcc: 0.8375 - val_precision: 0.8918 - val_recall: 0.8363 - val_sensitivity: 0.8363 - val_specificity: 0.9797 - learning_rate: 7.5000e-05
# Epoch 4/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 63us/step - accuracy: 0.9375 - auc: 0.9984 - f1_score: 0.9032 - loss: 0.2339 - mcc: 0.8853 - precision: 0.9333 - recall: 0.8750 - sensitivity: 0.8750 - specificity: 0.9875 - val_accuracy: 0.9000 - val_auc: 0.9960 - val_f1_score: 0.9474 - val_loss: 0.2499 - val_mcc: 0.9393 - val_precision: 1.0000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 1.0000 - learning_rate: 7.5000e-05
# Epoch 5/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9081 - auc: 0.9925 - f1_score: 0.9072 - loss: 0.2567 - mcc: 0.8890 - precision: 0.9174 - recall: 0.8972 - sensitivity: 0.8972 - specificity: 0.9838 - val_accuracy: 0.8913 - val_auc: 0.9898 - val_f1_score: 0.8908 - val_loss: 0.2969 - val_mcc: 0.8694 - val_precision: 0.9034 - val_recall: 0.8785 - val_sensitivity: 0.8785 - val_specificity: 0.9812 - learning_rate: 7.5000e-05
# Epoch 6/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 67us/step - accuracy: 0.7500 - auc: 0.9789 - f1_score: 0.7500 - loss: 0.5112 - mcc: 0.7000 - precision: 0.7500 - recall: 0.7500 - sensitivity: 0.7500 - specificity: 0.9500 - val_accuracy: 0.8000 - val_auc: 0.9870 - val_f1_score: 0.8000 - val_loss: 0.3493 - val_mcc: 0.7600 - val_precision: 0.8000 - val_recall: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.9600 - learning_rate: 7.5000e-05
# Epoch 7/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.9192 - auc: 0.9937 - f1_score: 0.9174 - loss: 0.2258 - mcc: 0.9011 - precision: 0.9251 - recall: 0.9098 - sensitivity: 0.9098 - specificity: 0.9853 - val_accuracy: 0.8855 - val_auc: 0.9881 - val_f1_score: 0.8867 - val_loss: 0.3202 - val_mcc: 0.8642 - val_precision: 0.8932 - val_recall: 0.8802 - val_sensitivity: 0.8802 - val_specificity: 0.9790 - learning_rate: 7.5000e-05
# Epoch 8/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 66us/step - accuracy: 0.8750 - auc: 0.9852 - f1_score: 0.8387 - loss: 0.3780 - mcc: 0.8083 - precision: 0.8667 - recall: 0.8125 - sensitivity: 0.8125 - specificity: 0.9750 - val_accuracy: 0.9000 - val_auc: 0.9920 - val_f1_score: 0.9000 - val_loss: 0.2418 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 7.5000e-05
# Epoch 9/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 77s 88ms/step - accuracy: 0.9373 - auc: 0.9963 - f1_score: 0.9359 - loss: 0.1754 - mcc: 0.9231 - precision: 0.9414 - recall: 0.9304 - sensitivity: 0.9304 - specificity: 0.9884 - val_accuracy: 0.7965 - val_auc: 0.9662 - val_f1_score: 0.7980 - val_loss: 0.5862 - val_mcc: 0.7583 - val_precision: 0.8079 - val_recall: 0.7884 - val_sensitivity: 0.7884 - val_specificity: 0.9625 - learning_rate: 7.5000e-05
# Epoch 10/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 74us/step - accuracy: 0.9375 - auc: 0.9992 - f1_score: 0.9375 - loss: 0.1155 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 0.5000 - val_auc: 0.9350 - val_f1_score: 0.5000 - val_loss: 1.2435 - val_mcc: 0.4000 - val_precision: 0.5000 - val_recall: 0.5000 - val_sensitivity: 0.5000 - val_specificity: 0.9000 - learning_rate: 7.2000e-05
# Epoch 11/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 77s 89ms/step - accuracy: 0.9529 - auc: 0.9976 - f1_score: 0.9523 - loss: 0.1402 - mcc: 0.9428 - precision: 0.9551 - recall: 0.9495 - sensitivity: 0.9495 - specificity: 0.9911 - val_accuracy: 0.9049 - val_auc: 0.9913 - val_f1_score: 0.9049 - val_loss: 0.2729 - val_mcc: 0.8861 - val_precision: 0.9127 - val_recall: 0.8971 - val_sensitivity: 0.8971 - val_specificity: 0.9828 - learning_rate: 6.9120e-05
# Epoch 12/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 67us/step - accuracy: 0.9375 - auc: 0.9992 - f1_score: 0.9375 - loss: 0.0877 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0525 - val_mcc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 6.6355e-05
# Epoch 13/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.9605 - auc: 0.9985 - f1_score: 0.9608 - loss: 0.1133 - mcc: 0.9530 - precision: 0.9634 - recall: 0.9582 - sensitivity: 0.9582 - specificity: 0.9927 - val_accuracy: 0.9151 - val_auc: 0.9926 - val_f1_score: 0.9146 - val_loss: 0.2374 - val_mcc: 0.8977 - val_precision: 0.9198 - val_recall: 0.9096 - val_sensitivity: 0.9096 - val_specificity: 0.9841 - learning_rate: 6.3701e-05
# Epoch 14/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 66us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 0.9677 - loss: 0.1225 - mcc: 0.9623 - precision: 1.0000 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 1.0000 - val_accuracy: 0.9000 - val_auc: 0.9940 - val_f1_score: 0.9000 - val_loss: 0.3217 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 6.1153e-05
# Epoch 15/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9644 - auc: 0.9988 - f1_score: 0.9643 - loss: 0.1019 - mcc: 0.9572 - precision: 0.9665 - recall: 0.9621 - sensitivity: 0.9621 - specificity: 0.9933 - val_accuracy: 0.7401 - val_auc: 0.9451 - val_f1_score: 0.7393 - val_loss: 0.8316 - val_mcc: 0.6879 - val_precision: 0.7476 - val_recall: 0.7311 - val_sensitivity: 0.7311 - val_specificity: 0.9506 - learning_rate: 5.8707e-05
# Epoch 16/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 68us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0598 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.7000 - val_auc: 0.9260 - val_f1_score: 0.7000 - val_loss: 1.1212 - val_mcc: 0.6400 - val_precision: 0.7000 - val_recall: 0.7000 - val_sensitivity: 0.7000 - val_specificity: 0.9400 - learning_rate: 5.6359e-05
# Epoch 17/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 87ms/step - accuracy: 0.9758 - auc: 0.9994 - f1_score: 0.9756 - loss: 0.0720 - mcc: 0.9707 - precision: 0.9764 - recall: 0.9747 - sensitivity: 0.9747 - specificity: 0.9953 - val_accuracy: 0.8727 - val_auc: 0.9831 - val_f1_score: 0.8729 - val_loss: 0.3776 - val_mcc: 0.8481 - val_precision: 0.8869 - val_recall: 0.8593 - val_sensitivity: 0.8593 - val_specificity: 0.9781 - learning_rate: 5.4104e-05
# Epoch 18/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - accuracy: 0.9375 - auc: 0.9992 - f1_score: 0.9375 - loss: 0.0842 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0491 - val_mcc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 5.1940e-05
# Epoch 19/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 74s 86ms/step - accuracy: 0.9833 - auc: 0.9996 - f1_score: 0.9838 - loss: 0.0536 - mcc: 0.9806 - precision: 0.9847 - recall: 0.9829 - sensitivity: 0.9829 - specificity: 0.9970 - val_accuracy: 0.8674 - val_auc: 0.9733 - val_f1_score: 0.8670 - val_loss: 0.5044 - val_mcc: 0.8405 - val_precision: 0.8698 - val_recall: 0.8642 - val_sensitivity: 0.8642 - val_specificity: 0.9741 - learning_rate: 4.9862e-05
# Epoch 20/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0090 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.9000 - val_auc: 0.9930 - val_f1_score: 0.9000 - val_loss: 0.4685 - val_mcc: 0.8800 - val_precision: 0.9000 - val_recall: 0.9000 - val_sensitivity: 0.9000 - val_specificity: 0.9800 - learning_rate: 4.7868e-05
# Epoch 21/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9874 - auc: 0.9998 - f1_score: 0.9871 - loss: 0.0409 - mcc: 0.9845 - precision: 0.9879 - recall: 0.9864 - sensitivity: 0.9864 - specificity: 0.9976 - val_accuracy: 0.9174 - val_auc: 0.9896 - val_f1_score: 0.9170 - val_loss: 0.2708 - val_mcc: 0.9004 - val_precision: 0.9191 - val_recall: 0.9148 - val_sensitivity: 0.9148 - val_specificity: 0.9839 - learning_rate: 4.5953e-05
# Epoch 22/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - accuracy: 0.9375 - auc: 0.9992 - f1_score: 0.9375 - loss: 0.0929 - mcc: 0.9250 - precision: 0.9375 - recall: 0.9375 - sensitivity: 0.9375 - specificity: 0.9875 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0347 - val_mcc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 4.4115e-05
# Epoch 23/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9903 - auc: 0.9999 - f1_score: 0.9904 - loss: 0.0313 - mcc: 0.9884 - precision: 0.9906 - recall: 0.9902 - sensitivity: 0.9902 - specificity: 0.9981 - val_accuracy: 0.9122 - val_auc: 0.9873 - val_f1_score: 0.9127 - val_loss: 0.2885 - val_mcc: 0.8952 - val_precision: 0.9140 - val_recall: 0.9113 - val_sensitivity: 0.9113 - val_specificity: 0.9828 - learning_rate: 4.2351e-05
# Epoch 24/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 0s 65us/step - accuracy: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - loss: 0.0121 - mcc: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0298 - val_mcc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 4.0656e-05
# Epoch 25/25
# 862/862 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.9934 - auc: 0.9999 - f1_score: 0.9932 - loss: 0.0260 - mcc: 0.9919 - precision: 0.9935 - recall: 0.9929 - sensitivity: 0.9929 - specificity: 0.9987 - val_accuracy: 0.8735 - val_auc: 0.9764 - val_f1_score: 0.8757 - val_loss: 0.4671 - val_mcc: 0.8512 - val_precision: 0.8830 - val_recall: 0.8686 - val_sensitivity: 0.8686 - val_specificity: 0.9770 - learning_rate: 3.9030e-05

# %%
execution_time = end_time - start_time

milliseconds = int(execution_time * 1000)
seconds, milliseconds = divmod(milliseconds, 1000)
minutes, seconds = divmod(seconds, 60)
hours, minutes = divmod(minutes, 60)

time_string = f"{hours} hours, " if hours else ""
time_string += f"{minutes} minutes, " if minutes else ""
time_string += f"{seconds} seconds, " if seconds else ""
time_string += f"{milliseconds} milliseconds"

print(f"Model training took {time_string}")
# Out:
# Model training took 17 minutes, 19 seconds, 596 milliseconds

# %%
test_steps = math.ceil(test_generator.samples / test_generator.batch_size)
_ = model.evaluate(test_generator, steps=test_steps)
# Out:
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 33s 105ms/step - accuracy: 0.9417 - auc: 0.9915 - f1_score: 0.9424 - loss: 0.2089 - mcc: 0.9310 - precision: 0.9468 - recall: 0.9381 - sensitivity: 0.9381 - specificity: 0.9895

# %%
def plot_metrics(hist, metric_name_list):
    num_metrics = len(metric_name_list)

    figure, axes = plt.subplots(num_metrics, figsize=(10, 6 * num_metrics))

    rng = range(1, len(hist.history[metric_name_list[0]]) + 1)

    for ax, metric_n in zip(axes, metric_name_list):
        metric = hist.history[metric_n]
        v_metric = hist.history[f"val_{metric_n}"]

        ax.plot(rng, metric, label=metric_n)
        ax.plot(rng, v_metric, label=f"val_{metric_n}")
        ax.legend()
        ax.set_xlabel("Epochs")

        if metric_n in ("auc", "mcc"):
            ax.set_ylabel(metric_n.upper())
            ax.set_title(metric_n.upper() + " vs Epochs")
        else:
            ax.set_ylabel(metric_n.capitalize())
            ax.set_title(metric_n.capitalize() + " vs Epochs")

        max_loss = max(max(metric), max(v_metric))
        min_loss = min(min(metric), min(v_metric))
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()

    plt.show()

# %%
metric_names = ["loss", "accuracy", "precision", "recall", "f1_score",
                "specificity", "sensitivity", "mcc", "auc"]
plot_metrics(history, metric_names)

# %%
def confusion_matrix(true_labels, predicted_labels, num_classes):
    cm = np.zeros((num_classes, num_classes), dtype=int)
    np.add.at(cm, (true_labels, predicted_labels), 1)
    return cm

# %%
cm = confusion_matrix(true_labels, predicted_labels, 6)

classes = list(train_generator.class_indices.keys())

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=classes, yticklabels=classes)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
